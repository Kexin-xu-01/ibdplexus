# %%
from PIL import Image

tiff_path = '/alan-data/jinc/share/data/ibd_clean_xavier/sparc-image-ffp/all_wsi_tiff/10407218HE1.tiff'

with Image.open("your_image.tif") as img:
    description = img.tag_v2.get(270)  # ImageDescription
    print(description)
# Out:
# Running cells with 'base (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n base ipykernel --update-deps --force-reinstall'
